# %%
import torch
import torch.nn as nn

conv_block = nn.Conv2d(3, 6, 3, 2)
x = torch.rand([3, 128, 128])

out = conv_block(x)

# %%
out.shape
# Out:
# torch.Size([6, 63, 63])

# %% [markdown]
# # ResNet

# %%
class ResnetModel(nn.Module):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
    def forward(self, x):
        pass
